# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - Identify commonly used open-source tools in Data Science
# - Create Markdown elements such as headers, lists, and tables
# - Perform simple arithmetic operations using Python code
# - Understand the structure and functionality of Jupyter Notebooks

# %% [markdown]
# Some of the popular languages that Data Scientists use are:

# %% [markdown]
# 1. Python
# 2. Java
# 3. R programming
# 4. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# 1. NumPy for numerical computing and array manipulation
# 2. pandas for data manipulation and analysis
# 3. Matplotlib for data visualization
# 4. scikitlearn for machine learning
# 5. TensorFlow for deep learning

# %% [markdown]
# | Data Science Tools             |
# |-------------------------------|
# | Jupyter Notebook              |
# | RStudio                       |
# | Apache Zeppelin               |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
(3*4)+5
# This a simple arithmetic expression to mutiply then add integers
# Out:
# 17

# %%
minutes = 200
hours = minutes / 60
print(f"{minutes} minutes is equal to {hours} hours")
# This will convert 200 minutes to hours by diving by 60
# Out:
# 200 minutes is equal to 3.3333333333333335 hours

# %% [markdown]
# ## Author
#
# Bipllab Roy
